# %% [markdown]
# # Tutorial: Forecasting Dengue Incidence in Brazil with Python and Machine Learning Models
#
# This notebook provides step-by-step instructions to complete the tutorial 'Forecasting Dengue Incidence in Brazil with Python and Machine Learning Models'. By the end of this tutorial, you should be comfortable loading and cleaning data, training your model, visualising and evaluating the outputs, and making small adjustments to the model structure.
#
# ## Anticipated Learning Outcomes
# 1. Design and evaluate forecasting models for infectious diseases
# 2. Implement the Python library 'DARTS' for performing time-series forecasting
# 3. Understand how to integrate covariate data into forecasting models of infectious disease
#
# ---
#
# **Google Colab**: We are using Colab for this tutorial, instructions to mount your Drive and configure your data filepath are below (see next cell).

# %% [markdown]
# ## Colab setup
# ### Load necessary packages and address dependency issues
# Before we get started we will load a newer version of the `numpy` package which is not always present by default on the colab runtime. This version is necessary for using `darts`.
#
# The `darts` package, contains a suite of useful functions and models for time series forecasting. We encourage you to [consult the `darts` documentation](https://unit8co.github.io/darts/) to learn more about the different model types and how they are implemented.
#
# ***As you run this cell you will be prompted to restart your runtime. The FIRST time this dialogue box appears, do not click restart as it will interrupt the rest of the cell from running; instead click 'cancel'. The SECOND time this dialogue box appears, click restart.***

# %%
# Uninstall any numpy the kernel knows about
# %pip uninstall -y numpy

# Force reinstall new numpy version and darts (no cache)
# %pip install --no-cache-dir --force-reinstall numpy==2.3.5
# %pip install --no-cache-dir --force-reinstall darts==0.41.0
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Collecting numpy==2.3.5
#   Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 68.4 MB/s eta 0:00:00
# Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 78.6 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.5 which is incompatible.
# Successfully installed numpy-2.3.5
# Collecting darts==0.41.0
#   Downloading darts-0.41.0-py3-none-any.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 6.3 MB/s eta 0:00:00
# Collecting holidays>=0.11.1 (from darts==0.41.0)
#   Downloading holidays-0.91-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 124.6 MB/s eta 0:00:00
# Collecting joblib>=0.16.0 (from darts==0.41.0)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting matplotlib>=3.3.0 (from darts==0.41.0)
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 222.1 MB/s eta 0:00:00
# Collecting narwhals>=1.25.1 (from darts==0.41.0)
#   Downloading narwhals-2.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting nfoursid>=1.0.0 (from darts==0.41.0)
#   Downloading nfoursid-1.0.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting numpy>=2.2.0 (from darts==0.41.0)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=2.2.0 (from darts==0.41.0)
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 239.8 MB/s eta 0:00:00
# Collecting pyod>=0.9.5 (from darts==0.41.0)
#   Downloading pyod-2.0.6-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 195.5 MB/s eta 0:00:00
# Collecting requests>=2.22.0 (from darts==0.41.0)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting scikit-learn<1.8.0,>=1.6.0 (from darts==0.41.0)
#   Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting scipy>=1.3.2 (from darts==0.41.0)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 250.2 MB/s eta 0:00:00
# Collecting shap>=0.40.0 (from darts==0.41.0)
#   Downloading shap-0.50.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (25 kB)
# Collecting statsmodels>=0.14.0 (from darts==0.41.0)
#   Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting tqdm>=4.60.0 (from darts==0.41.0)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 242.7 MB/s eta 0:00:00
# Collecting typing-extensions>=4.0.0 (from darts==0.41.0)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting xarray>=0.17.0 (from darts==0.41.0)
#   Downloading xarray-2026.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting python-dateutil<3,>=2.9.0.post0 (from holidays>=0.11.1->darts==0.41.0)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 204.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.3.0->darts==0.41.0)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting numba>=0.51 (from pyod>=0.9.5->darts==0.41.0)
#   Downloading numba-0.64.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.22.0->darts==0.41.0)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.22.0->darts==0.41.0)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.22.0->darts==0.41.0)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.22.0->darts==0.41.0)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<1.8.0,>=1.6.0->darts==0.41.0)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting slicer==0.0.8 (from shap>=0.40.0->darts==0.41.0)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting cloudpickle (from shap>=0.40.0->darts==0.41.0)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting patsy>=0.5.6 (from statsmodels>=0.14.0->darts==0.41.0)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.51->pyod>=0.9.5->darts==0.41.0)
#   Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Collecting six>=1.5 (from python-dateutil<3,>=2.9.0.post0->holidays>=0.11.1->darts==0.41.0)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading darts-0.41.0-py3-none-any.whl (744 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.5/744.5 kB 45.0 MB/s eta 0:00:00
# Downloading holidays-0.91-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 192.4 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 209.7 MB/s eta 0:00:00
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 178.1 MB/s eta 0:00:00
# Downloading narwhals-2.16.0-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.0/444.0 kB 136.0 MB/s eta 0:00:00
# Downloading nfoursid-1.0.2-py3-none-any.whl (18 kB)
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 233.0 MB/s eta 0:00:00
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 240.7 MB/s eta 0:00:00
# Downloading pyod-2.0.6-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.7/204.7 kB 311.0 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 219.7 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 231.8 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 236.0 MB/s eta 0:00:00
# Downloading shap-0.50.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 244.8 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 271.9 MB/s eta 0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 259.6 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 172.5 MB/s eta 0:00:00
# Downloading xarray-2026.2.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 326.0 MB/s eta 0:00:00
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 198.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 135.5 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 281.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 295.9 MB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 78.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 196.8 MB/s eta 0:00:00
# Downloading numba-0.64.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 238.4 MB/s eta 0:00:00
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 163.4 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 167.2 MB/s eta 0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 175.5 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 213.6 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 189.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 322.3 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 183.0 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: urllib3, typing-extensions, tqdm, threadpoolctl, slicer, six, pyparsing, pillow, packaging, numpy, narwhals, llvmlite, kiwisolver, joblib, idna, fonttools, cycler, cloudpickle, charset_normalizer, certifi, scipy, requests, python-dateutil, patsy, numba, contourpy, scikit-learn, pandas, matplotlib, holidays, xarray, statsmodels, shap, pyod, nfoursid, darts
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: slicer
#     Found existing installation: slicer 0.0.8
#     Uninstalling slicer-0.0.8:
#       Successfully uninstalled slicer-0.0.8
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.3.2
#     Uninstalling pyparsing-3.3.2:
#       Successfully uninstalled pyparsing-3.3.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.0
#     Uninstalling packaging-26.0:
#       Successfully uninstalled packaging-26.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
#   Attempting uninstall: narwhals
#     Found existing installation: narwhals 2.16.0
#     Uninstalling narwhals-2.16.0:
#       Successfully uninstalled narwhals-2.16.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.9
#     Uninstalling kiwisolver-1.4.9:
#       Successfully uninstalled kiwisolver-1.4.9
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.3
#     Uninstalling joblib-1.5.3:
#       Successfully uninstalled joblib-1.5.3
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.61.1
#     Uninstalling fonttools-4.61.1:
#       Successfully uninstalled fonttools-4.61.1
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.2
#     Uninstalling cloudpickle-3.1.2:
#       Successfully uninstalled cloudpickle-3.1.2
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.4
#     Uninstalling charset-normalizer-3.4.4:
#       Successfully uninstalled charset-normalizer-3.4.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2026.1.4
#     Uninstalling certifi-2026.1.4:
#       Successfully uninstalled certifi-2026.1.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: patsy
#     Found existing installation: patsy 1.0.2
#     Uninstalling patsy-1.0.2:
#       Successfully uninstalled patsy-1.0.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.3
#     Uninstalling contourpy-1.3.3:
#       Successfully uninstalled contourpy-1.3.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: holidays
#     Found existing installation: holidays 0.91
#     Uninstalling holidays-0.91:
#       Successfully uninstalled holidays-0.91
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.12.0
#     Uninstalling xarray-2025.12.0:
#       Successfully uninstalled xarray-2025.12.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.6
#     Uninstalling statsmodels-0.14.6:
#       Successfully uninstalled statsmodels-0.14.6
#   Attempting uninstall: shap
#     Found existing installation: shap 0.50.0
#     Uninstalling shap-0.50.0:
#       Successfully uninstalled shap-0.50.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.2 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 cloudpickle-3.1.2 contourpy-1.3.3 cycler-0.12.1 darts-0.41.0 fonttools-4.61.1 holidays-0.91 idna-3.11 joblib-1.5.3 kiwisolver-1.4.9 llvmlite-0.46.0 matplotlib-3.10.8 narwhals-2.16.0 nfoursid-1.0.2 numba-0.64.0 numpy-2.4.2 packaging-26.0 pandas-3.0.1 patsy-1.0.2 pillow-12.1.1 pyod-2.0.6 pyparsing-3.3.2 python-dateutil-2.9.0.post0 requests-2.32.5 scikit-learn-1.7.2 scipy-1.17.1 shap-0.50.0 six-1.17.0 slicer-0.0.8 statsmodels-0.14.6 threadpoolctl-3.6.0 tqdm-4.67.3 typing-extensions-4.15.0 urllib3-2.6.3 xarray-2026.2.0

# %% [markdown]
# You will see some errors at the end of the console output above, but this is just because our (hopefully) newly installed `numpy` version 2.3.5 conflicts with some default colab package versions. This is fine, as we won't be using those packages today. Now we will check that the correct versions of the packages are installed. You should see `numpy` version 2.3.5 (or later) and `darts` version 0.41.0. If you don't see this, please ask one of the demonstrators for help before proceeding.

# %%
import sys, numpy as np, darts
print("Python:", sys.version.split()[0])
print("NumPy:", np.__version__, np.__file__)
print("Darts:", darts.__version__)
# Out:
# Python: 3.12.12
# NumPy: 2.4.2 /usr/local/lib/python3.12/dist-packages/numpy/__init__.py
# Darts: 0.41.0

# %% [markdown]
# ### Mount Drive and set data path
#
#
# 1. Create a folder in your drive called `forecasting_tutorial` where you will later upload the data files for the practical
# 2. Run the cell below to mount Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Path to the folder containing: EPI CSV, NetCDF files (reanalysis, spe06, population, seasonal forecast).
DATA_DIR = '/content/drive/MyDrive/forecasting_tutorial'
# Out:
# Mounted at /content/drive

# %% [markdown]
# *Note that the folder you create in your drive can have any name, provided the filepath that `DATA_DIR` points to is updated accordingly to reflect the correct name and destination of the folder*

# %% [markdown]
# ---
#
# # 1. Data: Cleaning, understanding and preparing
#
# ## 1.1 Obtaining the data from Global.health
#
# First, we will obtain the data we will use in this practical from the [Global.health data repository](https://sim-dev-data.covid-19.global.health/data-downloads). For this you will need to sign in with your google account and be granted access by an admin.
#
# Our country of interest is Brazil, and the Brazil data files are housed on the repo with the prefix 'BRA':
#
#
# *   **`BRA_epi_training.csv`**
# *   `BRA-ccvi.zs.nc`
# *   `BRA-gdp_pc.zs.nc`
# *   `BRA_population.zs.nc`
# *   `BRA-reanalysis_monthly.zs.nc`
# *   `BRA-seasonal_forecast_monthly.zs.nc`
# *   `BRA_spa01.zs.nc`
# *   `BRA-spa03.zs.nc`
# *   `BRA-spa06.zs.nc`
# *   `BRA_spa12.zs.nc`
# *   `BRA_spe01.zs.nc`
# *   `BRA-spe03.zs.nc`
# *   `BRA-spe06.zs.nc`
# *   `BRA_spe12.zs.nc`
# *   `BRA-surv_wmean.zs.nc`
# *   `BRA-svwl1.zs.nc`
# *   `BRA_w_piped.zs.nc`
#
# While at first, we will run a univariate model that predicts cases without using any of these predictor datasets, during data prep we will get the full data ready. Accordingly, you should download each of these datasets and place them in the directory on your google drive indicated by `DATA_DIR` (unless you have chosen a different name, this is probably `forecasting_tutorial`).
#
# ### Descriptions of the data
# More information on each of the datasets are available on [the tutorial github](https://github.com/kraemer-lab/Dengue_Forecasting_Tutorial/tree/main/data). We encourage you to read this information to familiarise yourself with what data is available, which will be particularly helpful later in the tutorial and for your assignment.

# %% [markdown]
# ## 1.2 Full data integration
#
# We merge the epidemiological target (dengue cases) which is stored in `BRA_epi_training.csv` with historical covariates and seasonal forecasts from NetCDF files. The result is a single table with cases, log(cases+1), and covariates per region and month.

# %%
import os
import pandas as pd
import xarray as xr

def to_month_end(date_series):
    """Align dates to the last day of the month."""
    return pd.to_datetime(date_series) + pd.offsets.MonthEnd(0)

# --- Paths (all under DATA_DIR) ---
epi_file = os.path.join(DATA_DIR, 'BRA_epi_training.csv')
fc_file = os.path.join(DATA_DIR, 'BRA-seasonal_forecast_monthly.zs.nc')
hist_files = {
    os.path.join(DATA_DIR, 'BRA-reanalysis_monthly.zs.nc'): None,
    os.path.join(DATA_DIR, 'BRA-spe06.zs.nc'): None,
    os.path.join(DATA_DIR, 'BRA-population.zs.nc'): {'population': 'pop_count'}
}

# 1. Load target data (EPI)
df_epi = pd.read_csv(epi_file)
df_epi['Region'] = df_epi['Region'].astype(int)
df_epi['Date'] = to_month_end(df_epi['Month'])
df_epi = df_epi.drop(columns=['Month', 'Unnamed: 0'], errors='ignore')
if df_epi.duplicated(subset=['Region', 'Date']).any():
    df_epi = df_epi.groupby(['Region', 'Date']).mean(numeric_only=True).reset_index()

df_final = df_epi.copy()

# 2. Historical covariates (standard merge)
print("Merging historical covariates...")
for f, rename_map in hist_files.items():
    if not os.path.exists(f):
        continue
    ds = xr.open_dataset(f)
    df_nc = ds.to_dataframe().reset_index()
    ds.close()
    df_nc.rename(columns=lambda x: x.lower() if x in ['time', 'region'] else x, inplace=True)
    df_nc.rename(columns={'time': 'Date', 'region': 'Region'}, inplace=True)
    df_nc['Region'] = pd.to_numeric(df_nc['Region'], errors='coerce')
    df_nc.dropna(subset=['Region'], inplace=True)
    df_nc['Region'] = df_nc['Region'].astype(int)
    df_nc['Date'] = to_month_end(df_nc['Date'])
    cols_drop = [c for c in df_nc.columns if c in ['spatial_ref', 'crs', 'bnds', 'month_number']]
    df_nc.drop(columns=cols_drop, inplace=True, errors='ignore')
    if rename_map:
        df_nc.rename(columns=rename_map, inplace=True)
    if df_nc.duplicated(subset=['Region', 'Date']).any():
        df_nc = df_nc.groupby(['Region', 'Date']).mean(numeric_only=True).reset_index()
    df_final = pd.merge(df_final, df_nc, on=['Region', 'Date'], how='left')

# 3. Seasonal forecast cube (flatten leads 1..6 into columns)
fc_cols = []
if os.path.exists(fc_file):
    print("Processing seasonal forecast cube...")
    ds = xr.open_dataset(fc_file)
    df_fc = ds.to_dataframe().reset_index()
    ds.close()
    df_fc.rename(columns=lambda x: x.lower() if x in ['time', 'region', 'month'] else x, inplace=True)
    df_fc.rename(columns={'time': 'Date', 'region': 'Region'}, inplace=True)
    df_fc['Region'] = pd.to_numeric(df_fc['Region'], errors='coerce')
    df_fc.dropna(subset=['Region'], inplace=True)
    df_fc['Region'] = df_fc['Region'].astype(int)
    df_fc['Date'] = to_month_end(df_fc['Date'])
    value_vars = [c for c in df_fc.columns if c not in ['Region', 'Date', 'month', 'spatial_ref', 'crs']]
    df_pivoted = df_fc.pivot_table(index=['Region', 'Date'], columns='month', values=value_vars)
    df_pivoted.columns = [f"{col}_L{lead}" for col, lead in df_pivoted.columns]
    df_pivoted = df_pivoted.reset_index()
    df_final = pd.merge(df_final, df_pivoted, on=['Region', 'Date'], how='left')
    fc_cols = [c for c in df_pivoted.columns if c not in ['Region', 'Date']]
    print(f"  Added {len(fc_cols)} forecast features.")
else:
    print("Seasonal forecast file not found; skipping.")

# Interpolate / forward-fill where needed
df_final.sort_values(['Region', 'Date'], inplace=True)
if 'pop_count' in df_final.columns:
    df_final['pop_count'] = df_final.groupby('Region')['pop_count'].transform(lambda x: x.interpolate(limit_direction='both'))
if fc_cols:
    df_final[fc_cols] = df_final.groupby('Region')[fc_cols].transform(lambda x: x.ffill())

# Target for modelling: log(cases + 1)
df_final['LogCases'] = np.log1p(df_final['Cases'])

df_final.sort_values(by=['Region', 'Date'], inplace=True)
outfile = os.path.join(DATA_DIR, 'BRA_integrated_forecasting_data.csv')
#df_final.to_csv(outfile, index=False)
#print(f"Saved to {outfile}")
print("Columns:", df_final.columns.tolist())
# Out:
# Merging historical covariates...
# Processing seasonal forecast cube...
#   Added 30 forecast features.
# Columns: ['Country', 'Region', 'Cases', 'Spatial_Resolution', 'Date', 't2m', 'rh', 'tp', 'spe06', 'pop_count', 'area', 'pop_density', 'mn2t24_L1.0', 'mn2t24_L2.0', 'mn2t24_L3.0', 'mn2t24_L4.0', 'mn2t24_L5.0', 'mn2t24_L6.0', 'mx2t24_L1.0', 'mx2t24_L2.0', 'mx2t24_L3.0', 'mx2t24_L4.0', 'mx2t24_L5.0', 'mx2t24_L6.0', 'rh_L1.0', 'rh_L2.0', 'rh_L3.0', 'rh_L4.0', 'rh_L5.0', 'rh_L6.0', 't2m_L1.0', 't2m_L2.0', 't2m_L3.0', 't2m_L4.0', 't2m_L5.0', 't2m_L6.0', 'tp_L1.0', 'tp_L2.0', 'tp_L3.0', 'tp_L4.0', 'tp_L5.0', 'tp_L6.0', 'LogCases']

# %% [markdown]
# After running this chunk, a number of new data frames will be available in the data inspector. These include:
#
#
#
# *   `df_epi`: a data frame of epi cases by region (municipality) in Brazil
# *   `df_fc`: a data frame consisting of seasonal forecasts flattened into columns (and `df_pivoted`, a pivoted version of this used as an intermediate step)
# *   `df_nc`: a data frame of historical covariates
# *   `df_final`: a data frame we can use for the rest of the tutorial which has, for each date, the forecast target (log transformed cases) and covariate values.

# %% [markdown]
# > ***THEORY BREAK: HISTORICAL VS FORECASTED COVARIATES - WHAT'S THE DIFFERENCE??***
# >
# > *When forecasting dengue, it’s important to distinguish between historically observed predictor data and forecasted predictor data. For a date like June 1, 2015, the observed temperature is the value that was actually measured on that day. In contrast, forecasted temperatures are predictions made ahead of time — for example, what temperature was predicted on April 1 or May 1 for June 1. These values differ because forecasts are made with incomplete information and uncertainty, so they may not match what ultimately occurred. When building models retrospectively, using observed covariates can show how well a model could perform with perfect knowledge of the future. However, in real-time forecasting, we sometimes must use the forecasted covariates that would have been available at the time to avoid using information from the future. This setup also highlights the three-dimensional nature of forecasts: each value depends not only on the date being predicted, but also on when the forecast was issued. As a result, the same calendar date can have multiple forecasted values, one from each prior forecast date - this is why we had to 'flatten' the seasonal forecast dataset.*

# %% [markdown]
# ## 1.3 Filter to Rio de Janeiro and explore
#
# Our processed data has multiple concurrent time series for every municipality in Brazil (more than 5,000!). While the most thorough forecasting models will forecast for all of these locations together (and may also use information from different municipalities to 'help' each other), for now we will keep it simple and focus on a single time series. For this first section, we are going to focus on the **municipality of Rio de Janeiro**, identified by `Region == 3304557`.

# %%
RIO_REGION = 3304557  # Municipality of Rio de Janeiro

df_rio = df_final[df_final['Region'] == RIO_REGION].sort_values('Date').copy()
df_rio = df_rio.dropna(subset=['LogCases'])

print(f"Rio de Janeiro (Region {RIO_REGION}): {len(df_rio)} months")
print(f"Date range: {df_rio['Date'].min()} to {df_rio['Date'].max()}")
df_rio[['Date', 'Cases', 'LogCases']].head(10)
# Out:
# Rio de Janeiro (Region 3304557): 107 months
# Date range: 2014-12-31 00:00:00 to 2023-10-31 00:00:00
#              Date  Cases  LogCases
# 346363 2014-12-31     30  3.433987
# 346364 2015-01-31    220  5.398163
# 346365 2015-02-28    353  5.869297
# 346366 2015-03-31   1478  7.299121
# 346367 2015-04-30   4441  8.398860
# 346368 2015-05-31   5861  8.676246
# 346369 2015-06-30   3216  8.076205
# 346370 2015-07-31   1387  7.235619
# 346371 2015-08-31   1098  7.002156
# 346372 2015-09-30    517  6.249975

# %% [markdown]
# To help us to understand the data, we will use `matplotlib` to generate a plot of cases and log-transformed cases.

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6), sharex=True)
ax1.plot(df_rio['Date'], df_rio['Cases'], color='steelblue')
ax1.set_ylabel('Cases')
ax1.set_title('Dengue cases (raw) - Rio de Janeiro')
ax2.plot(df_rio['Date'], df_rio['LogCases'], color='darkgreen')
ax2.set_ylabel('Log(Cases+1)')
ax2.set_title('Log(Cases+1) - Rio de Janeiro')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 2. Model: Temporal Convolutional Network Model (6‑month horizon, no covariates)
#
# Now that we have our data cleaned, processed, and ready to go, it's time to build our first forecasting model! We will focus on the data we have subset from Rio de Janeiro for now, and build a forecasting model using **cases only - no covariates**.
#
# We will use the `darts` python library, which specialises in time series manipulation and forecasting. We'll fit a **TCN (Temporal Convolutional Network)** model.
#
# ### About TCN Models
# TCN models model time series objects by using convolutions over time to learn patterns in past data. The model looks back at a window of past values (the 'signal'), e.g. the last 10 months of dengue cases and detects patterns such as trends or seasonality, which it can use to produce a forecast.
#
# ### TCNs in practice
# In practice, using TCNs you can specify many different parameters that we will explore today, some of which include:
# *   `input_chunk_length`: how big the 'window of past values' should be (also can be called 'context window')
# *   `output_chunk_length`: how far ahead the model should predict (also can be called 'forecast horizon'.
# *   `kernel_size`: the width of the convolutional filter. A kernel size of 3 means each convolution looks at 3 adjacent time steps at a time when extracting patterns.
# *   `num_filters`: the number of convolutional filters in each layer. More filters allow the model to learn more distinct temporal features, but increase model complexity.
# *   `dropout`: this helps prevent overfitting by randomly “turning off” some proportion of neurons during training.
# *   `likelihood`: controls whether forecasts are deterministic (i.e. only generating a single point prediction) or probablistic (i.e. predict a range of plausible futures)

# %% [markdown]
# ## Load packages and dependencies

# %%
# %pip install -q pytorch_lightning

import torch
import uuid
from darts import TimeSeries
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.utils.missing_values import fill_missing_values
from darts.dataprocessing.transformers import Scaler
from darts.models import TCNModel
from darts.utils.likelihood_models import QuantileRegression

HORIZON = 6
INPUT_CHUNK_LENGTH = 24
OUTPUT_CHUNK_LENGTH = 6
NUM_SAMPLES = 500  # for probabilistic forecasts (CRPS, WIS)
# Out:
# WARNING:darts.models:The StatsForecast module could not be imported. To enable support for the AutoARIMA, AutoETS and Croston models, please consider installing it.

# %% [markdown]
# In the above code chunk we install and load the necessary packages, and specify some parameters. The forecast horizon (and thus, output chunk length) is set to 6 months, the input chunk length is set to 24 months, and the number of samples (i.e. number of 'guesses' the forecast model should take is set to 500.
#
# **The idea of taking multiple samples is a very important part of forecasting** - A single point forecast hides the uncertainty inherent in predicting complex systems like dengue transmission. Generating multiple forecast samples allows us to represent the full range of plausible futures and quantify uncertainty through prediction intervals. These forecast windows are more informative for decision-making and enable proper evaluation of probabilistic accuracy, rather than relying only on point-error metrics.

# %% [markdown]
# ## Divide data into training and testing sets
#
# Next we will format our data into time series objects, and divide it into our training and testing sets by providing a `split_date` - all data before this date will be used to train the model, and data after this date can be used for testing.. The training sets will be used to (you guessed it) train the model, and the testing set will be used to evaluate the model performance. It's important that you separate the data into these folds to prevent leakage, i.e., the model accidentally 'seeing' and learning from future data, which will then bias the results when you test on that data.

# %%
# Build univariate time series (log scale)
ts_target = TimeSeries.from_dataframe(
    df_rio, time_col='Date', value_cols='LogCases', freq='ME'
)
ts_target = fill_missing_values(ts_target)

# Train / test split (you can change the split or use your own holdout)
# Example: train up to mid 2022, test from mid 2022 onwards
split_date = pd.Timestamp('2022-06-30')
train_target = ts_target.drop_after(split_date)
test_target = ts_target.drop_before(split_date)

print(f"Train: {train_target.start_time()} to {train_target.end_time()} ({len(train_target)} points)")
print(f"Test:  {test_target.start_time()} to {test_target.end_time()} ({len(test_target)} points)")
# Out:
# Train: 2014-12-31 00:00:00 to 2022-05-31 00:00:00 (90 points)
# Test:  2022-07-31 00:00:00 to 2023-10-31 00:00:00 (16 points)

# %% [markdown]
# ## Define and fit our model
# Next we will train the TCN model on our training data. First we specify the `model` structure using `TCNModel()`, then train the model using `model.fit()`.

# %%
# Scale the target for training (fit on train only)
scaler = Scaler()
train_scaled = scaler.fit_transform(train_target)

model = TCNModel(
    input_chunk_length=INPUT_CHUNK_LENGTH,  # Look back 24 months
    output_chunk_length=OUTPUT_CHUNK_LENGTH,  # Forecast 6 months
    kernel_size=3,
    num_filters=32,
    dilation_base=2,
    dropout=0.1,
    likelihood=QuantileRegression(), # <--- Generates probabilistic samples
    random_state=42,
    model_name="TCN_univariate",
    force_reset=True,
    save_checkpoints=False,
    pl_trainer_kwargs={"accelerator": "cpu"}
)

model.fit(series = train_scaled, verbose=False)
print("TCN fit complete.")
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# TCN fit complete.

# %% [markdown]
# ## Predict from the trained model
# Now we will use our trained forecasting model to make a prediction. We will sample many predictions from our model (`NUM_SAMPLES`) and summarise these using quantiles. This will generate another data frame in the Data inspector called `df_forecast`, which holds our predictions.

# %%
# Predict 6 months ahead
pred_scaled = model.predict(
    n=HORIZON,
    series=train_target,
    num_samples=NUM_SAMPLES
)

# Inverse Transform (Scales back the values, keeps the samples structure)
pred_log = scaler.inverse_transform(pred_scaled)

print(f"Prediction Shape: {pred_log.values().shape} (Time, Components, Samples)")

# Compute Quantiles and Store in Data Frame
QUANTILES = [0.01, 0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]
results = {'Date': pred_log.time_index}

for q in QUANTILES:
    # .quantile(q) reduces the samples to a single value per time step
    q_series = pred_log.quantile(q)
    results[f"q{q:.2f}"] = q_series.values().flatten()

df_forecast = pd.DataFrame(results).set_index('Date')
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Prediction Shape: (6, 1) (Time, Components, Samples)

# %% [markdown]
# ---
#
# # 3. Visualisation and evaluation
#
# When we wish to explore how well our forecasts align with what is actually observed, we can plot them visually in addition to calculating performance metrics. Here, we will do both.
#
# ## 3.1 Visualising your predictions
#
# To visualise out predictions, we will plot them alongside some of the held out testing data:

# %%
# Get Ground Truth for the forecast period + some history
full_actual = ts_target.slice(split_date - pd.DateOffset(months=INPUT_CHUNK_LENGTH), split_date + pd.DateOffset(months=HORIZON))
df_actual = pd.DataFrame({
    'Actual': full_actual.values().flatten()
}, index=full_actual.time_index)

# Merge for perfect alignment on the plot
df_plot = df_actual.join(df_forecast, how='outer')

plt.figure(figsize=(12, 6))

# Plot History (Black)
plt.plot(df_plot.index, df_plot['Actual'], color='black', label='Actual History', linewidth=1.5)

# Plot Forecast (Blue)
# We filter to where we actually have forecasts
subset = df_plot.dropna(subset=['q0.50'])

plt.plot(subset.index, subset['q0.50'], color='blue', label='Median Forecast', linewidth=2, linestyle='--')

# Fan Chart
plt.fill_between(subset.index, subset['q0.05'], subset['q0.95'], color='blue', alpha=0.1, label='90% CI')
plt.fill_between(subset.index, subset['q0.25'], subset['q0.75'], color='blue', alpha=0.3, label='50% CI')

plt.title(f"TCN Probabilistic Forecast (Time Series Only, No Covariates)\nRio de Janeiro, 6-month forecast")
plt.xlabel("Date")
plt.ylabel("Log(Cases)")
plt.legend(loc='upper left')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## 3.2 Why scoring rules? Calibration and sharpness
# When we have probabilistic forecasts (e.g. many samples or quantiles), we care about:
#
# *   **Calibration**: Do prediction intervals contain the true value the stated proportion of the time? (e.g. 90% intervals should contain the observation about 90% of the time.)
# *   **Sharpness**: How narrow are the intervals? We prefer narrower intervals when they are well calibrated.
#
# A proper scoring rule is a single number that summarises how well the forecast distribution matches the data-generating process, or the true distribution. These can be used to express calibration and sharpness. Using a proper score avoids incentives to report overconfident or underconfident forecasts.
#
# Here we will look at three metrics:
#
# *   **RMSE (root mean squared error):** For point forecasts (e.g. median). Lower is better. It does not assess calibration or full distribution and thus does not evaluate the full predictive distribution.
# *   **CRPS (Continuous Ranked Probability Score):** For probabilistic forecasts that generate a distribution of samples. It evaluates the entire predictive distribution by measuring how close the forecast cumulative distribution is to the observed outcome. Lower is better.
# *   **WIS (Weighted Interval Score):** For quantile (or interval) forecasts. It combines interval width and penalties when the observation falls outside the interval. Lower is better. It approximates CRPS and is a proper scoring rule for quantile forecasts.
#
#
# Other metrics you might report: MAE, coverage of central intervals (e.g. 50%, 90%), mean interval width

# %% [markdown]
# ## 3.3 RMSE (point forecast)
#
# Next we will calculate RMSE of the median forecast vs actual cases. RMSE (Root Mean Squared Error) is a commonly used metric to evaluate the accuracy of point forecasts. It measures the average magnitude of the errors between predicted values and observed values. Here's how to interpret it:
#
# *   **Magnitude of Error**: RMSE provides a single, aggregate measure of prediction error. The value of RMSE is in the same units as the predicted variable (in our case, `LogCases` or `Cases` if transformed back).
# *   **Lower is Better**: A lower RMSE value indicates a better fit of the model to the data. This means the predictions are closer to the actual observations.
# *   **Sensitivity to Large Errors**: Because errors are squared before they are averaged, RMSE gives a relatively high weight to large errors. This means it's particularly useful when large errors are undesirable and should be penalized more heavily than smaller errors.
# *   **Comparison**: RMSE is most useful when comparing different models or different configurations of the same model. For instance, if Model A has an RMSE of 1.5 and Model B has an RMSE of 0.8, Model B is generally considered more accurate.
# *   **Context is Key**: While a lower RMSE is always better, what constitutes a 'good' RMSE value is highly dependent on the context and the scale of the data. For example, an RMSE of 1.0 might be excellent for predicting a variable that ranges from 0 to 1000, but poor for a variable that ranges from 0 to 10.

# %%
from darts.metrics import rmse

# Get the median prediction from the probabilistic forecast (log scale)
pred_median_log = pred_log.quantile(0.5)

# On log scale (common for modelling)
rmse_log = rmse(test_target[:HORIZON], pred_median_log)
print(f"RMSE (log scale): {rmse_log:.4f}")
# Out:
# RMSE (log scale): 0.3695

# %% [markdown]
# ## 3.4 CRPS (Continuous Ranked Probability Score)
#
# CRPS is a *proper scoring rule* for probabilistic forecasts, meaning it provides a fair and comprehensive evaluation of an entire forecast distribution (not just a single point prediction). It measures the difference between the forecast cumulative distribution function (CDF) and the empirical CDF of the observed outcome. Here's a breakdown of its interpretation:
#
# *   **Evaluates the Full Distribution**: Unlike metrics such as RMSE or MAE that only assess point forecasts, CRPS considers the entire predicted probability distribution. This means it rewards forecasts that are both accurate (their central tendency is close to the observed value) and sharp (their uncertainty is narrow).
# *   **Units**: CRPS is in the same units as the observed variable (in our case, `LogCases`). This makes it intuitively understandable; a CRPS of 1.0 means, on average, the probabilistic forecast is "off" by about 1 unit on the log scale.
# *   **Lower is Better**: A lower CRPS value indicates a better forecast. A perfect deterministic forecast (where the predicted value equals the observed value) would have a CRPS of zero.
# *   **Relationship to MAE**: For deterministic forecasts (a single point prediction), CRPS simplifies to the Mean Absolute Error (MAE). For probabilistic forecasts, it can be thought of as a generalization of MAE that accounts for the entire distribution.
# *   **Robustness**: CRPS is less sensitive to outliers than squared-error metrics like RMSE, as it uses absolute differences rather than squared differences in its underlying calculation. This makes it a robust measure for evaluating forecast accuracy in many contexts.
# *   **Comparison**: CRPS is particularly useful for comparing different probabilistic forecasting models. A model yielding a lower CRPS is generally considered superior, as its forecast distributions are, on average, closer to the true data-generating process.
#
# For an ensemble of samples, we use the mean CRPS over time steps. We compute it on the **log scale** (where the model is defined); you can also report it on the cases scale if you convert samples accordingly.

# %%
# CRPS from samples (log scale)
# %pip install -q properscoring
try:
    import properscoring as ps
    HAS_PS = True
except ImportError:
    HAS_PS = False

if HAS_PS:
    # pred_log has shape (samples, time, 1)
    samples = pred_log.all_values()  # (n_timesteps, n_components, n_samples)
    # For univariate: (n_timesteps, 1, n_samples) -> (n_timesteps, n_samples)
    forecast_ensemble = np.moveaxis(samples, -1, 0)  # (n_samples, n_timesteps, 1)
    obs = test_target[:HORIZON].values().flatten()
    crps_vals = []
    for t in range(min(HORIZON, len(obs))):
        crps_t = ps.crps_ensemble(obs[t], forecast_ensemble[:, t, 0])
        crps_vals.append(crps_t)
    crps_mean = np.mean(crps_vals)
    print(f"CRPS (log scale, mean over horizon): {crps_mean:.4f}")
else:
    print("Install properscoring for CRPS: pip install properscoring")
# Out:
# CRPS (log scale, mean over horizon): 0.8476

# %% [markdown]
# ## 3.5 WIS (Weighted Interval Score)
#
# WIS is defined from symmetric quantile pairs and the median, and is a comprehensive proper scoring rule specifically designed for evaluating *quantile forecasts* or *interval forecasts*. For each pair (e.g. 0.05 and 0.95), we compute the interval score (width + penalties if the observation is outside). WIS is a weighted average of these plus the median absolute error. Lower is better.
#
# *   **Proper Scoring Rule**: Like CRPS, WIS is a proper scoring rule. This means it provides an unbiased and comprehensive evaluation of the forecast, encouraging forecasters to state their true beliefs about the future.
# *   **Combines Sharpness and Calibration**: WIS considers both the width of the prediction intervals (sharpness) and whether the actual observation falls within those intervals (calibration). It penalizes wide intervals and also penalizes instances where the observation falls outside the predicted intervals.
# *   **Weighted Average of Interval Scores**: WIS is calculated as a weighted average of scores for various prediction intervals (e.g., 50%, 90%). For each interval, a score is computed based on its width and penalties if the observed value falls outside its bounds. The median forecast also contributes to the score (similar to MAE).
# *   **Lower is Better**: A lower WIS value indicates a superior forecast. This means the forecast is both sharp (narrow prediction intervals) and well-calibrated (the true values fall within the intervals at the expected frequency).
# *   **Approximation of CRPS**: WIS can be seen as an approximation of CRPS, especially when using a sufficient number of quantile levels. For practical purposes, it's often preferred for quantile forecasts because it directly leverages the quantile structure.
# *   **Units**: Similar to CRPS and RMSE, WIS is in the same units as the observed variable (e.g., `LogCases`). This provides an intuitive understanding of the average "error" of the probabilistic forecast.

# %%
def wis_from_quantiles(actual, q_dict):
    """
    WIS for one observation given quantile predictions.
    q_dict: e.g. {0.05: val, 0.5: median, 0.95: val, ...}
    """
    if np.isnan(actual):
        return np.nan
    qs = sorted(q_dict.keys())
    K = len(qs) // 2
    median = q_dict.get(0.5)
    if median is None:
        median = q_dict[qs[len(qs)//2]]
    wis_sum = 0.5 * np.abs(actual - median)
    for k in range(K):
        alpha = 2 * qs[k]
        L = q_dict[qs[k]]
        U = q_dict[qs[-(k+1)]]
        score = (U - L)
        if actual < L:
            score += (2 / alpha) * (L - actual)
        if actual > U:
            score += (2 / alpha) * (actual - U)
        wis_sum += score
    return wis_sum / (K + 0.5)

# Build quantile dict per time step (log scale)
quantiles_wis = [0.05, 0.25, 0.5, 0.75, 0.95]
obs_log = test_target[:HORIZON].values().flatten()
wis_scores = []
for t in range(min(HORIZON, len(obs_log))):
    q_dict = {q: pred_log.quantile(q).values()[t, 0] for q in quantiles_wis}
    wis_t = wis_from_quantiles(obs_log[t], q_dict)
    wis_scores.append(wis_t)

wis_mean = np.nanmean(wis_scores)
print(f"WIS (log scale, mean over horizon): {wis_mean:.4f}")
# Out:
# WIS (log scale, mean over horizon): 7.5043

# %% [markdown]
# ---
# # 4. Introducing Covariates
#
# Now that we have fitted our first simple time series model, we can add some complexity by introducing covariates.
#
#
# > ***THEORY BREAK: WHY MIGHT WE WANT TO INCORPORATE COVARIATES IN OUR MODEL??***
# >
# > *When forecasting dengue, it is often useful to include environmental covariates such as temperature or precipitation because these factors directly influence mosquito biology and virus transmission dynamics. Temperature affects mosquito development rates, survival, biting frequency, and viral replication within the mosquito, while rainfall can create or eliminate breeding sites. As a result, changes in environmental conditions can precede changes in dengue incidence, providing early signals that improve predictive performance. Including these covariates allows the model to move beyond purely statistical patterns in past case counts and instead incorporate mechanistic drivers of transmission. In theory, this can improve both short-term accuracy and the model’s ability to generalize across seasons or unusual climate conditions.*
#
# In this next example, we will adjust our model from before to include temperature as a covariate.
#
# ## Prepare the extra data
# We will select temperature (`t2m`) from the master data frame we assembled earlier, and use this as a predictor in our model. The other data (training and testing data for the forecast target, epidemiological cases) is still available from earlier, so we don't need to reformat that again.

# %%
# Build time series of temperature
cov_cols = ['t2m']

ts_covs = TimeSeries.from_dataframe(df_rio, time_col='Date', value_cols=cov_cols, freq='ME')
ts_covs = fill_missing_values(ts_covs)

# Train / test split (you can change the split or use your own holdout)
# Same split date as before
train_covs = ts_covs.drop_after(split_date)
test_covs = ts_covs.drop_before(split_date)

print(f"Train: {train_covs.start_time()} to {train_covs.end_time()} ({len(train_covs)} points)")
print(f"Test:  {test_covs.start_time()} to {test_covs.end_time()} ({len(test_covs)} points)")

scaler_covs = Scaler()
ts_covs_scaled = scaler_covs.fit_transform(ts_covs)
# Out:
# Train: 2014-12-31 00:00:00 to 2022-05-31 00:00:00 (90 points)
# Test:  2022-07-31 00:00:00 to 2023-10-31 00:00:00 (16 points)

# %% [markdown]
# ## Fit the model
# We will define, fit and predict from our model using the same approach as before, but this time include `past_covariates` in the call to `model.fit`:

# %%
model_temperature = TCNModel(
    input_chunk_length=INPUT_CHUNK_LENGTH,  # Look back 24 months
    output_chunk_length=OUTPUT_CHUNK_LENGTH,  # Forecast 6 months
    kernel_size=3,
    num_filters=32,
    dilation_base=2,
    dropout=0.1,
    likelihood=QuantileRegression(), # <--- Generates probabilistic samples
    random_state=42,
    model_name="TCN_withtemperature",
    force_reset=True,
    save_checkpoints=False,
    pl_trainer_kwargs={"accelerator": "cpu"}
)

model_temperature.fit(
    series=train_scaled,
    past_covariates=ts_covs_scaled,
    epochs=30,
    verbose=True
)

# Predict 6 months ahead
pred_scaled = model_temperature.predict(
    n=HORIZON,
    series=train_target,
    past_covariates=ts_covs_scaled,
    num_samples=NUM_SAMPLES
)

# Inverse Transform (Scales back the values, keeps the samples structure)
pred_log = scaler.inverse_transform(pred_scaled)

print(f"Prediction Shape: {pred_log.values().shape} (Time, Components, Samples)")

# Compute Quantiles and Store in Data Frame
QUANTILES = [0.01, 0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]
results = {'Date': pred_log.time_index}

for q in QUANTILES:
    # .quantile(q) reduces the samples to a single value per time step
    q_series = pred_log.quantile(q)
    results[f"q{q:.2f}"] = q_series.values().flatten()

df_forecast = pd.DataFrame(results).set_index('Date')
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ┏━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name            ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ criterion       │ MSELoss          │      0 │ train │     0 │
# │ 1 │ train_criterion │ MSELoss          │      0 │ train │     0 │
# │ 2 │ val_criterion   │ MSELoss          │      0 │ train │     0 │
# │ 3 │ train_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 4 │ val_metrics     │ MetricCollection │      0 │ train │     0 │
# │ 5 │ res_blocks      │ ModuleList       │ 14.9 K │ train │     0 │
# └───┴─────────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 14.9 K
# Non-trainable params: 0
# Total params: 14.9 K
# Total estimated model params size (MB): 0
# Modules in train mode: 23
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Prediction Shape: (6, 1) (Time, Components, Samples)

# %% [markdown]
# ---
#
# # Exercises
#
# Below are example solutions to the exercises given during the tutorial. To run these, it's important to run the rest of the notebook first, as the code below relies on the packages imported and variables defined earlier.

# %% [markdown]
# ## Exercise 1: Visualise the results of the temperature model trained in Section 4
#
# ***Repeat the visualisation process we used for our initial univariate model to produce a plot of the model we just fitted using temperature as a covariate.***
#
# ### Exercise 1 Solution
# #### Code explanation
# **Lines 1-4**: In our graph, we will be comparing our forecast results to what actually occurred. Below, we make a data frame (`df_actual`) that contains the actual case data, from the beginning of our input chunk to the end of our forecast horizon.
#
# **Line 7**: We merge what 'actually happened' (`df_actual`) from above, with our predictions that we generated and saved from the temperature model in the previous code block (`df_forecast`). We put these together in a single data frame `df_plot` for easy plotting.
#
# **Line 9**: We initialise the plot.
#
# **Line 12**: We plot what actually happened. Here you can see that we indicate using `df_plot['Actual']` that we use the `Actual` column of the data frame. If you look back at line 3, you can find where we first gave the column that name. Line 12 is what creates the black line on the final plot that shows the 'Actual History'.
#
#
#
# > *Exercise to expand your understanding: Try to change the colour of the black line on the plot by changing line 12!*
#
#
#
# **Line 16**: We subset the plotting data frame to where we have forecasts. In our forecast results dataset, there won't be results for the entire period - just the output chunk up to the horizon. This line filters out the NAs for the time period beforehand to make sure those don't mess up the plot.
#
# **Line 18**: We add a dashed line (`linestyle='--'`) showing the median forecast to the plot. The median forecast is accessed by it's corresponding quantile (`q0.50`).
#
# **Lines 21-22**: We add shaded regions showing the 90% (i.e., between `q0.05` and `q0.95`) and 50% confidence intervals of the forecast. These intervals show where most of those predictions fell from the 500 predictions we made from the model (remember `NUM_SAMPLES = 500`?).
#
# **Lines 24-28**: Bread and butter plotting code.
#
# **Line 29**: Telling colab to show us the plot!

# %%
full_actual = ts_target.slice(split_date - pd.DateOffset(months=INPUT_CHUNK_LENGTH), split_date + pd.DateOffset(months=HORIZON))
df_actual = pd.DataFrame({
    'Actual': full_actual.values().flatten()
}, index=full_actual.time_index)

# Merge for perfect alignment on the plot
df_plot = df_actual.join(df_forecast, how='outer')

plt.figure(figsize=(12, 6))

# Plot History (Black)
plt.plot(df_plot.index, df_plot['Actual'], color='black', label='Actual History', linewidth=1.5)

# Plot Forecast (Blue)
# We filter to where we actually have forecasts
subset = df_plot.dropna(subset=['q0.50'])

plt.plot(subset.index, subset['q0.50'], color='blue', label='Median Forecast', linewidth=2, linestyle='--')

# Fan Chart
plt.fill_between(subset.index, subset['q0.05'], subset['q0.95'], color='blue', alpha=0.1, label='90% CI')
plt.fill_between(subset.index, subset['q0.25'], subset['q0.75'], color='blue', alpha=0.3, label='50% CI')

plt.title(f"TCN Probabilistic Forecast (Temperature Covariate)\nRio de Janeiro, 6-month forecast")
plt.xlabel("Date")
plt.ylabel("Log(Cases)")
plt.legend(loc='upper left')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# #### Understanding what we've done
#
# You'll notice that we didn't make any changes to this plotting code compared to what we used earlier. Why is it that we didn't have to change anything? After all, we have run a completely new model!
#
# Well, if you look at the code chunk above this, where we ran and predicted from our new temperature model, on line 45 you'll see that we wrote our results to `df_forecast`. This is the same dataframe we used to store our results from the first model we ran and plotted. So when we saved our results from our new model, we overwrote the results from the first model, and now `df_forecast` points to the results from our temperature model. So, we can use our old plotting code, which looks for `df_forecast`, and when it finds it, it finds our new results!

# %% [markdown]
# ---
# ## Exercise 2: Change the horizon of the temperature model to 3 months
#
# ***Refit the TCN temperature model to the Rio de Janeiro data with a **3‑month** forecast horizon instead of 6.***
#
# >**Hints**
# >
# > Revisit the `HORIZON` and `OUTPUT_CHUNK_LENGTH` arguments.
#
# ### Exercise 2 Solution
# #### Code Explanation
# **Lines 2-3**: Redefining our `OUTPUT_CHUNK_LENGTH` and `HORIZON` arguments to reflect a horizon of 3 instead of 6.
#
# **Lines 6-19**: Defining our model using the same code as we used before. We've already taken care of changing the horizon by adjusting our variable values in lines 2 and 3. The only change we make here is giving the model a new name (adding a `_horiz3`) so that our earlier model object is not overwritten.
#
# **Lines 22-27**: Fitting the model using the same code from before, by calling the function (`.fit()`) on the model object we just defined in lines 6-19. However, we must be careful that we call `fit` on the correct model! Our new model is called `model_temperature_horiz3`, so we have updated the code on line 22 to reflect this name and make sure we identify the correct model.
#
# **Lines 30-35**: Predict from our new trained model. As before, it's important to make sure we are predicting using the correct (new) model. Accordingly, line 30 has been changed slightly from the code previously used in the tutorial to reflect this new name. Pretty much everything else stays the same compared to earlier.
#
# **Line 38**: Back transform the predictions. We transformed the data before putting it into the model (wayyyyy back at the beginning of the tutorial), so this line just transforms it back using the same scaler.
#
# **Line 40**: Print out some characteristics of the predictions.
#
# **Line 43**: Start an object called 'results' that will contain a summary of our predictions (which we will shortly calculate inside the for loop in the following lines)
#
# **Lines 44-47**: A `for` loop, which cycles through all of the `quantiles` defined in an earlier code chunk in this tutorial (*challenge: try to find where `quantiles` was defined!*). For each quantile value 'q', it uses the predictions from the model to calculate the predicted value below which 'q' proportion of predictions have fallen. It saves this value to the `results` object that we defined above.
#
# > *UNDERSTANDING QUANTILES INTUITIVELY: If the above description confused you - don't worry. Basically, quantiles in a dengue incidence prediction tell you the levels below which a certain percentage of possible future case counts are expected to fall. For example, the 90th percentile (q = 0.9) means we expect actual dengue cases to be lower than that value 90% of the time, capturing uncertainty in the forecast.*
#
# **Line 49**: Coerces our results object into a dataframe called `df_forecast_horiz3`. By giving it this name it ensures our previous forecast outputs from earlier exercises are not overwritten.

# %%
# Redefine some of the parameters from earlier
HORIZON = 3
OUTPUT_CHUNK_LENGTH = 3

# Define the model
model_temperature_horiz3 = TCNModel(
    input_chunk_length=INPUT_CHUNK_LENGTH,  # Look back 24 months
    output_chunk_length=OUTPUT_CHUNK_LENGTH,  # Forecast 3 months
    kernel_size=3,
    num_filters=32,
    dilation_base=2,
    dropout=0.1,
    likelihood=QuantileRegression(), # <--- Generates probabilistic samples
    random_state=42,
    model_name="TCN_withtemperature_3monthhorizon",
    force_reset=True,
    save_checkpoints=False,
    pl_trainer_kwargs={"accelerator": "cpu"}
)

# Fit (train) the model
model_temperature_horiz3.fit(
    series=train_scaled,
    past_covariates=ts_covs_scaled,
    epochs=30,
    verbose=True
)

# Predict 3 months ahead
pred_scaled_horiz3 = model_temperature_horiz3.predict(
    n=HORIZON,
    series=train_target,
    past_covariates=ts_covs_scaled,
    num_samples=NUM_SAMPLES
)

# Inverse Transform (Scales back the values, keeps the samples structure)
pred_log_horiz3 = scaler.inverse_transform(pred_scaled_horiz3)

print(f"Prediction Shape: {pred_log_horiz3.values().shape} (Time, Components, Samples)")

# Compute Quantiles and Store in Data Frame
results = {'Date': pred_log_horiz3.time_index}
for q in QUANTILES:
    # .quantile(q) reduces the samples to a single value per time step
    q_series = pred_log_horiz3.quantile(q)
    results[f"q{q:.2f}"] = q_series.values().flatten()

df_forecast_horiz3 = pd.DataFrame(results).set_index('Date')
# Out:
# ┏━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name            ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ criterion       │ MSELoss          │      0 │ train │     0 │
# │ 1 │ train_criterion │ MSELoss          │      0 │ train │     0 │
# │ 2 │ val_criterion   │ MSELoss          │      0 │ train │     0 │
# │ 3 │ train_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 4 │ val_metrics     │ MetricCollection │      0 │ train │     0 │
# │ 5 │ res_blocks      │ ModuleList       │ 15.3 K │ train │     0 │
# └───┴─────────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 15.3 K
# Non-trainable params: 0
# Total params: 15.3 K
# Total estimated model params size (MB): 0
# Modules in train mode: 23
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Prediction Shape: (3, 1) (Time, Components, Samples)

# %% [markdown]
# #### Understanding what we've done
#
# A lot of this exercise concerned small alterations to earlier code. Firstly, and most importantly, we adjusted some of the arguments, or parameters, of our model, to change the horizon to 3 months.
#
# Then (and this is non-essential but preferable), we adjusted the name of our model to reflect the 3 month horizon and prevent overwriting previous objects. It's important to understand that sometimes introducing a name change to an object in python will trigger errors further down the code unless you make sure future references to this renamed object use the new name. Not the most glamourous adjustments to make to the code, but an important lesson to learn!

# %% [markdown]
# ---
# # Exercise 3: Fit a TCN model with relative humidity
#
# ***Refit the TCN temperature model to the Rio de Janeiro data using relative humidity (`rh`) instead of temperature (`t2m`) and calculate the model CRPS and WIS.***
#
# >**Hints**
# >
# > Revisit the `cov_cols` variable.
#
# ## Exercise 3 Solution
# ### Code Explanation
# **Line 2**: Redefine `cov_cols`, which we used earlier to select temperature (`t2m`) to now contain `rh` (relative humidity).
#
# **Line 4**: Create a time series by selecting whatever is in `cov_cols` from the `rio_df` dataframe. Because we just changed `cov_cols` to `rh`, this line will take the `rh` column from the data we prepared at the start of the tutorial and use it in the model.
#
# **Line 5:** fill any gaps
#
# **Lines 8-53:** Very similar model definition, fitting and prediction code to what we used in Section 4 to make the temperature model. Our new model relies on humidity, because on line 4 earlier we updated `ts_covs` to use the humidity data instead of temperature.
#
# **Lines 55-64**: Calculate CRPS of our new model.
#
# > *WHY NOT COPY AND PASTE THE FULL CRPS CHUNK FROM EARLIER?*
# >
# > *Lots of lines in the original code chunk during the tutorial where we introduced CRPS were concerned with making sure the necessary packages were downloaded. We've done that already; we don't need to do it again. Sometimes when you are reusing code it can be tempting to copy and paste extra lines that aren't necessary to rerun. This isn't technically wrong, but can sometimes introduce errors or bugs if you're not careful. This also applies to WIS below.*
#
# **Lines 66-76**: Calculate WIS of our new model.

# %%
# Change cov_cols to contain 'rh' instead of 't2m' and get the data from the rio dataframe
cov_cols = ['rh']

ts_covs = TimeSeries.from_dataframe(df_rio, time_col='Date', value_cols=cov_cols, freq='ME')
ts_covs = fill_missing_values(ts_covs)

# Divide the covariate data into the same train / test split (Same split date as before)
train_covs = ts_covs.drop_after(split_date)
test_covs = ts_covs.drop_before(split_date)

# Scale covariate data
scaler_covs = Scaler()
ts_covs_scaled = scaler_covs.fit_transform(ts_covs)

# Changing back to 6 month horizon
HORIZON = 6
OUTPUT_CHUNK_LENGTH = 6

# Define our model, giving it a new name
model_humidity = TCNModel(
    input_chunk_length=INPUT_CHUNK_LENGTH,  # Look back 24 months
    output_chunk_length=OUTPUT_CHUNK_LENGTH,  # Forecast 6 months
    kernel_size=3,
    num_filters=32,
    dilation_base=2,
    dropout=0.1,
    likelihood=QuantileRegression(), # <--- Generates probabilistic samples
    random_state=42,
    model_name="TCN_withhumidity",
    force_reset=True,
    save_checkpoints=False,
    pl_trainer_kwargs={"accelerator": "cpu"}
)

model_humidity.fit(
    series=train_scaled,
    past_covariates=ts_covs_scaled,
    epochs=30,
    verbose=True
)

# Predict 6 months ahead
pred_scaled_humidity = model_humidity.predict(
    n=HORIZON,
    series=train_target,
    past_covariates=ts_covs_scaled,
    num_samples=NUM_SAMPLES
)

# Inverse Transform (Scales back the values, keeps the samples structure)
pred_log_humidity = scaler.inverse_transform(pred_scaled_humidity)

print(f"Prediction Shape: {pred_log_humidity.values().shape} (Time, Components, Samples)")

# CRPS of our new model (log scale)
samples = pred_log_humidity.all_values()
forecast_ensemble = np.moveaxis(samples, -1, 0)
obs = test_target[:HORIZON].values().flatten()
crps_vals = []
for t in range(min(HORIZON, len(obs))):
    crps_t = ps.crps_ensemble(obs[t], forecast_ensemble[:, t, 0])
    crps_vals.append(crps_t)
crps_mean = np.mean(crps_vals)
print(f"CRPS (log scale, mean over horizon): {crps_mean:.4f}")

# Build quantile dict per time step (log scale)
quantiles_wis = [0.05, 0.25, 0.5, 0.75, 0.95]
obs_log = test_target[:HORIZON].values().flatten()
wis_scores = []
for t in range(min(HORIZON, len(obs_log))):
    q_dict = {q: pred_log_humidity.quantile(q).values()[t, 0] for q in quantiles_wis}
    wis_t = wis_from_quantiles(obs_log[t], q_dict)
    wis_scores.append(wis_t)

wis_mean = np.nanmean(wis_scores)
print(f"WIS (log scale, mean over horizon): {wis_mean:.4f}")
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ┏━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name            ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ criterion       │ MSELoss          │      0 │ train │     0 │
# │ 1 │ train_criterion │ MSELoss          │      0 │ train │     0 │
# │ 2 │ val_criterion   │ MSELoss          │      0 │ train │     0 │
# │ 3 │ train_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 4 │ val_metrics     │ MetricCollection │      0 │ train │     0 │
# │ 5 │ res_blocks      │ ModuleList       │ 14.9 K │ train │     0 │
# └───┴─────────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 14.9 K
# Non-trainable params: 0
# Total params: 14.9 K
# Total estimated model params size (MB): 0
# Modules in train mode: 23
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Prediction Shape: (6, 1) (Time, Components, Samples)
# CRPS (log scale, mean over horizon): 3.3656
# WIS (log scale, mean over horizon): 14.1386

# %% [markdown]
# ### Understanding what we've done
# Much of the code used here is similar to earlier examples, but we see here how selecting a different data source `rh` instead of `t2m` from the `df_rio` table, which is achieved using a single line of code, can give us a brand new model.

# %% [markdown]
# ---
# # Exercise 4: Evaluate 4 different environmental variables as predictors of dengue cases
#
# ***Refit individual TCN models for Rio de Janeiro data using four environmental covariates of your choosing from the dataset. Evaluate each model's performance using RMSE, CRPS and WIS, and report the best performing model***
#
# >**Hints**
# >
# > Revisit the `cov_cols` variable.
# >
# > Use `for` loops to save rewriting code.
#
# ## Exercise 4 Solution
# ### Code Explanation
# **Chunk 1 Line 2**: Print out the column names of the `df_rio` data frame which has all our Rio de Janeiro data. The column names here indicate available covariates that we processed from those files earlier.

# %%
# Print out the columns in df_rio to see what covariates we might be able to use
print(list(df_rio))
# Out:
# ['Country', 'Region', 'Cases', 'Spatial_Resolution', 'Date', 't2m', 'rh', 'tp', 'spe06', 'pop_count', 'area', 'pop_density', 'mn2t24_L1.0', 'mn2t24_L2.0', 'mn2t24_L3.0', 'mn2t24_L4.0', 'mn2t24_L5.0', 'mn2t24_L6.0', 'mx2t24_L1.0', 'mx2t24_L2.0', 'mx2t24_L3.0', 'mx2t24_L4.0', 'mx2t24_L5.0', 'mx2t24_L6.0', 'rh_L1.0', 'rh_L2.0', 'rh_L3.0', 'rh_L4.0', 'rh_L5.0', 'rh_L6.0', 't2m_L1.0', 't2m_L2.0', 't2m_L3.0', 't2m_L4.0', 't2m_L5.0', 't2m_L6.0', 'tp_L1.0', 'tp_L2.0', 'tp_L3.0', 'tp_L4.0', 'tp_L5.0', 'tp_L6.0', 'LogCases']

# %% [markdown]
# **Chunk 2 Line 2**: Makes a list `cov_cols` with the names of the four covariates we are going to use - here we've just picked the first four covariates printed out from the list above (`Country, Region, Spatial_Resolution, Date` are not environmental covariates, and `Cases` are our target - not a covariate)
#
# **Chunk 2 Lines 4-5**: Import the `logging` package that enables us to have a little more control about what information shows up in the console when the code runs. Here we just specify that we don't need to know as much about the internal pytorch operations that take place when our model runs, which previously were getting printed out. Silencing those will make it easier for us to spot the interesting bits in our output when we later print the results of each model evaluation to the console.
#
# > *CHALLENGE: Those pytorch messages looked like this:*
# >
# > **INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False**
# >
# > *Try to find a line like that in an earlier code block!*
#
# **Chunk 2 Line 8**: ***Defining a for loop [IMPORTANT!]***. Here we define a for loop using the line `for covariate in cov_cols:`. The result is that the indented code below this line (Lines 9-80) will run once for each item in `cov_cols`. Because `cov_cols` has 4 items, the code will repeat 4 times. Most of the code stays the same, but `covariate` will change each time the for loop runs, to the corresponding item in `cov_cols`. For example, the first time the loop runs, `covariate` will equal `t2m`. Second time = `rh`, third time = `tp`. Easy peasy!
#
# **Chunk 2 Lines 9-80**: Very similar data processing (`lines 10-20`), model defining (`lines 22-36`), model fitting (`lines 39-44`), predicting (`lines 46-56`) and evaluating (`lines 59-80`) code to what we used before. These lines repeat 4 times, using a new value for `covariate` each time and printing out the results.

# %%
# Make a list of covariates
cov_cols = ['t2m', 'rh', 'tp', 'spe06']

import logging
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

# Make a for loop
for covariate in cov_cols:
    print(f"Running model for {covariate}")
    # Important! The below line is where the change happens each for loop ('covariate' is different each time)
    ts_covs = TimeSeries.from_dataframe(df_rio, time_col='Date', value_cols=covariate, freq='ME')
    ts_covs = fill_missing_values(ts_covs)

    # Divide the covariate data into the same train / test split (Same split date as before)
    train_covs = ts_covs.drop_after(split_date)
    test_covs = ts_covs.drop_before(split_date)

    # Scale covariate data
    scaler_covs = Scaler()
    ts_covs_scaled = scaler_covs.fit_transform(ts_covs)

    # Define our model
    model_insideloop = TCNModel(
        input_chunk_length=INPUT_CHUNK_LENGTH,  # Look back 24 months
        output_chunk_length=OUTPUT_CHUNK_LENGTH,  # Forecast 6 months
        kernel_size=3,
        num_filters=32,
        dilation_base=2,
        dropout=0.1,
        likelihood=QuantileRegression(), # <--- Generates probabilistic samples
        random_state=42,
        model_name="TCN",
        force_reset=True,
        save_checkpoints=False,
        pl_trainer_kwargs={"accelerator": "cpu"}
    )

    # Fit model
    model_insideloop.fit(
        series=train_scaled,
        past_covariates=ts_covs_scaled,
        epochs=30,
        verbose=False
    )

    # Predict 6 months ahead
    pred_scaled_insideloop = model_insideloop.predict(
        n=HORIZON,
        series=train_target,
        past_covariates=ts_covs_scaled,
        num_samples=NUM_SAMPLES,
        verbose=False
    )

    # Inverse Transform (Scales back the values, keeps the samples structure)
    pred_log_insideloop = scaler.inverse_transform(pred_scaled_insideloop)

    # CRPS of our model (log scale)
    samples = pred_log_insideloop.all_values()
    forecast_ensemble = np.moveaxis(samples, -1, 0)
    obs = test_target[:HORIZON].values().flatten()
    crps_vals = []
    for t in range(min(HORIZON, len(obs))):
        crps_t = ps.crps_ensemble(obs[t], forecast_ensemble[:, t, 0])
        crps_vals.append(crps_t)
    crps_mean = np.mean(crps_vals)
    print(f"CRPS for {covariate} model: {crps_mean:.4f}")

    # Build quantile dict per time step (log scale)
    quantiles_wis = [0.05, 0.25, 0.5, 0.75, 0.95]
    obs_log = test_target[:HORIZON].values().flatten()
    wis_scores = []
    for t in range(min(HORIZON, len(obs_log))):
        q_dict = {q: pred_log_insideloop.quantile(q).values()[t, 0] for q in quantiles_wis}
        wis_t = wis_from_quantiles(obs_log[t], q_dict)
        wis_scores.append(wis_t)

    # Calculate WIS
    wis_mean = np.nanmean(wis_scores)
    print(f"WIS for {covariate} model: {wis_mean:.4f}\n")
# Out:
# Running model for t2m
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# CRPS for t2m model: 5.0471
# WIS for t2m model: 19.1951
#
# Running model for rh
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# CRPS for rh model: 3.3656
# WIS for rh model: 14.1386
#
# Running model for tp
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# CRPS for tp model: 5.0017
# WIS for tp model: 18.3674
#
# Running model for spe06
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# CRPS for spe06 model: 3.7188
# WIS for spe06 model: 14.9296

# %% [markdown]
# ### Understanding what we've done
# With very few extra lines of code, we've run a lot of extra models. This is the beauty of the `for` loop! On balance, looking at the CRPS and WIS scores, it seems like the `spe06` model is the best performing model (remember, lower is better!). `spe06` is a drought index and seeing as drought has been shown to influence mosquito breeding behaviour and population dynamics, maybe this is why the model is performing best.
#
# **Common Pitfalls with `for` loops**
#
#
# *   Python is very picky about indentation. Make sure any code you want repeated by the for loop is indented below the beginning of the for loop, and there are no non-indented lines in between. A non-indented line signals to python that the loop code is over.
# *   Make sure that any variables that need to change are in fact changed between the iterations of the for loop! For example, if we hadn't used the iterator `covariate` to select the new covariate data each time on `line 11`, the model would not have changed between iterations of the for loop.

# %% [markdown]
# ---
# # Exercise 5: Fit a multivariate model with your predictors from 4
#
# ***Refit a TCN model for Rio de Janeiro data that uses all four environmental covariates of your choosing in a single model. Evaluate the model's performance using RMSE, CRPS and WIS, and visualise the predictions.***
#
# >**Hints**
# >
# > The `cov_cols` variable is a list that can contain multiple variable names.
# >
#
# ## Exercise 5 Solution
#
# ### Code Explanation
# **Line 2**: Brings back our list of covariates. Technically we defined this in the previous exercise, but lets redefine it here so all the code is together.
#
# **Line 5**: Makes a time series object by getting the selected covariates from `df_rio`. Where previously we would select only one covariate by giving a single value to `value_cols` (*remember using the iterator `covariate` to cycle through values in Exercise 5?*), here we are just giving it the full list (`cov_cols`). This creates a time series object using **all** of the covariates selected in `cov_cols`.
#
# **Lines 6-115**: Model fitting code that should all look very familiar by now! Pretty much no edits have been made to this compared to earlier, with the exception of renaming various objects and variables with the `_multi` tag to indicate for ourselves that this is a multivariate model. (And changing the plot to green, for a change of scenery).

# %%
# Use our list of covariates
cov_cols = ['t2m', 'rh', 'tp', 'spe06']

# Make a time series object, this time using the whole list cov_cols
ts_covs_multi = TimeSeries.from_dataframe(df_rio, time_col='Date', value_cols=cov_cols, freq='ME')
ts_covs_multi = fill_missing_values(ts_covs_multi)

# Divide the covariate data into the same train / test split (Same split date as before)
train_covs_multi = ts_covs_multi.drop_after(split_date)
test_covs_multi = ts_covs_multi.drop_before(split_date)

# Scale covariate data
scaler_covs_multi = Scaler()
ts_covs_scaled_multi = scaler_covs_multi.fit_transform(ts_covs_multi)

# Define our model
multivariate_model = TCNModel(
    input_chunk_length=INPUT_CHUNK_LENGTH,  # Look back 24 months
    output_chunk_length=OUTPUT_CHUNK_LENGTH,  # Forecast 6 months
    kernel_size=3,
    num_filters=32,
    dilation_base=2,
    dropout=0.1,
    likelihood=QuantileRegression(), # <--- Generates probabilistic samples
    random_state=42,
    model_name="TCN_multivariate",
    force_reset=True,
    save_checkpoints=False,
    pl_trainer_kwargs={"accelerator": "cpu"}
)

# Fit model
multivariate_model.fit(
    series=train_scaled,
    past_covariates=ts_covs_scaled,
    epochs=30,
    verbose=False
)

# Predict 6 months ahead
pred_scaled_multi = multivariate_model.predict(
    n=HORIZON,
    series=train_target,
    past_covariates=ts_covs_scaled_multi,
    num_samples=NUM_SAMPLES,
    verbose=False
)

# Inverse Transform (Scales back the values, keeps the samples structure)
pred_log_multi = scaler.inverse_transform(pred_scaled_multi)

# CRPS of our model (log scale)
samples = pred_log_multi.all_values()
forecast_ensemble = np.moveaxis(samples, -1, 0)
obs = test_target[:HORIZON].values().flatten()
crps_vals = []
for t in range(min(HORIZON, len(obs))):
    crps_t = ps.crps_ensemble(obs[t], forecast_ensemble[:, t, 0])
    crps_vals.append(crps_t)
crps_mean = np.mean(crps_vals)
print(f"CRPS for multivariate model: {crps_mean:.4f}")

# Build quantile dict per time step (log scale)
quantiles_wis = [0.05, 0.25, 0.5, 0.75, 0.95]
obs_log = test_target[:HORIZON].values().flatten()
wis_scores = []
for t in range(min(HORIZON, len(obs_log))):
    q_dict = {q: pred_log_multi.quantile(q).values()[t, 0] for q in quantiles_wis}
    wis_t = wis_from_quantiles(obs_log[t], q_dict)
    wis_scores.append(wis_t)

# Calculate WIS
wis_mean = np.nanmean(wis_scores)
print(f"WIS for multivariate  model: {wis_mean:.4f}\n")

# Compute Quantiles and Store in Data Frame
QUANTILES = [0.01, 0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]
results = {'Date': pred_log_multi.time_index}

for q in QUANTILES:
    # .quantile(q) reduces the samples to a single value per time step
    q_series = pred_log_multi.quantile(q)
    results[f"q{q:.2f}"] = q_series.values().flatten()

df_forecast_multi = pd.DataFrame(results).set_index('Date')

full_actual = ts_target.slice(split_date - pd.DateOffset(months=INPUT_CHUNK_LENGTH), split_date + pd.DateOffset(months=HORIZON))
df_actual = pd.DataFrame({
    'Actual': full_actual.values().flatten()
}, index=full_actual.time_index)

# Merge for perfect alignment on the plot
df_plot = df_actual.join(df_forecast_multi, how='outer')

plt.figure(figsize=(12, 6))

# Plot History (Black)
plt.plot(df_plot.index, df_plot['Actual'], color='black', label='Actual History', linewidth=1.5)

# Plot Forecast (Blue)
# We filter to where we actually have forecasts
subset = df_plot.dropna(subset=['q0.50'])

plt.plot(subset.index, subset['q0.50'], color='green', label='Median Forecast', linewidth=2, linestyle='--')

# Fan Chart
plt.fill_between(subset.index, subset['q0.05'], subset['q0.95'], color='green', alpha=0.1, label='90% CI')
plt.fill_between(subset.index, subset['q0.25'], subset['q0.75'], color='green', alpha=0.3, label='50% CI')

plt.title(f"TCN Probabilistic Forecast (Multivariate)\nRio de Janeiro, 6-month forecast")
plt.xlabel("Date")
plt.ylabel("Log(Cases)")
plt.legend(loc='upper left')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# CRPS for multivariate model: 4.8904
# WIS for multivariate  model: 27.9318

# %% [markdown]
# ### Understanding what we've done
#
# This exercise is an example of how a relatively small change (passing a list instead of a single string or item to a function) can transform a model completely. By passing *multi*ple covariates to the model at once, it becomes a *multi*variate model that uses all of these variables together to make its predictions. This often improves model performance, but not always - as you can see here!
